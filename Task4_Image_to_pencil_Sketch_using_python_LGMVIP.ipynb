# %% [markdown]
# <a href="https://colab.research.google.com/github/khatrikajal/LGMVIP/blob/main/Task4_Image_to_pencil_Sketch_using_python_LGMVIP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Task4- Image to pencil sketch using python **
# ---

# %%
import cv2
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

# %%
# Load the image
image_path = "/content/chotabhim.jpg"  
original_img = cv2.imread(image_path)

# %%
cv2_imshow(original_img)
plt.title('Original Image')
plt.axis('off')
plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1280x1024 at 0x7F96A2FFF670>

# %%
# Convert the image to grayscale
gray_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(gray_img)
plt.title('Grayscale Image')
plt.axis('off')
plt.show()
# Out:
# <PIL.Image.Image image mode=L size=1280x1024 at 0x7F96A3421A20>

# %%
# Invert the grayscale image to create a negative effect
negative_img = cv2.bitwise_not(gray_img)

# %%
cv2_imshow(negative_img)
plt.title('Negative Image')
plt.axis('off')
plt.show()
# Out:
# <PIL.Image.Image image mode=L size=1280x1024 at 0x7F96A0EE66E0>

# %%
# Apply Gaussian blur to the negative image
blurred_img = cv2.GaussianBlur(negative_img, (21, 21), sigmaX=0, sigmaY=0)

# %%
cv2_imshow(blurred_img)
plt.title('Blurred Image')
plt.axis('off')
plt.show()
# Out:
# <PIL.Image.Image image mode=L size=1280x1024 at 0x7F96A30AD510>

# %%
# Divide the grayscale image by the blurred negative image to create the sketch
sketch_img = cv2.divide(gray_img, 255 - blurred_img, scale=256)

# %%
cv2_imshow(sketch_img)
plt.title('Pencil Sketch')
plt.axis('off')
plt.show()
# Out:
# <PIL.Image.Image image mode=L size=1280x1024 at 0x7F96A2FD2260>
